# %% [markdown]
# # Prepping Data

# %%
import numpy as np

import pandas as pd
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

import json

#!conda install -c conda-forge geopy --yes
#from geopy.geocoders import Nominatim 

import requests 
from pandas.io.json import json_normalize 

# Matplotlib and associated plotting modules
import matplotlib.cm as cm
import matplotlib.colors as colors

# import k-means from clustering stage
from sklearn.cluster import KMeans

#import folium # map rendering library

print('Libraries imported.')
# Out:
# Libraries imported.

# %% [markdown]
# # Connect to Wikipedia and Clean for Data

# %%
# !wget -q -O 'Canada.json' https://en.wikipedia.org/wiki/List_of_postal_codes_of_Canada:_M
print('Data downloaded!')
# Out:
# Data downloaded!

# %%
url = 'https://en.wikipedia.org/wiki/List_of_postal_codes_of_Canada:_M'.format(Postcode, Borough, Neighbourhood)
url

# %%
#results = requests.get(url).json()
#results

# %%
# assign relevant part of JSON to venues
Canada = results['response']['venues']

# tranform venues into a dataframe
dataframe = json_normalize(venues)
dataframe.head()

# %%
filtered_columns = ['name', 'categories'] + [col for col in dataframe.columns if col.startswith('location.')] + ['id']
dataframe_filtered = dataframe.loc[:, filtered_columns]

# %% [markdown]
# ## Scrubbing Data for Use

# %%
data = pd.read_csv("Canada.csv")

# %%
Canada_df = data[data.Borough != 'Not assigned']

# %%
Canada_df['Neighborhood'].fillna(Canada_df['Borough'])
# Out:
# 1                                                  Rouge
# 2                                                Malvern
# 3                                         Highland Creek
# 4                                             Rouge Hill
# 5                                             Port Union
# 6                                              Guildwood
# 7                                            Morningside
# 8                                              West Hill
# 9                                                 Woburn
# 10                                             Cedarbrae
# 11                                   Scarborough Village
# 12                                  East Birchmount Park
# 13                                               Ionview
# 14                                          Kennedy Park
# 15                                              Clairlea
# 16                                           Golden Mile
# 17                                              Oakridge
# 18                                            Cliffcrest
# 19                                             Cliffside
# 20                              Scarborough Village West
# 21                                           Birch Cliff
# 22                                        Cliffside West
# 23                                           Dorset Park
# 24                               Scarborough Town Centre
# 25                                       Wexford Heights
# 26                                              Maryvale
# 27                                               Wexford
# 28                                             Agincourt
# 29                                        Clarks Corners
# 30                                              Sullivan
# 31                                         Tam O'Shanter
# 32                                       Agincourt North
# 33                                       L'Amoreaux East
# 34                                              Milliken
# 35                                          Steeles East
# 36                                       L'Amoreaux West
# 37                                           Upper Rouge
# 45                                     Hillcrest Village
# 46                                              Fairview
# 47                                            Henry Farm
# 48                                                Oriole
# 49                                       Bayview Village
# 50                                          Silver Hills
# 51                                            York Mills
# 52                                           Newtonbrook
# 53                                            Willowdale
# 54                                      Willowdale South
# 55                                       York Mills West
# 56                                       Willowdale West
# 64                                             Parkwoods
# 65                                       Don Mills North
# 66                                       Flemingdon Park
# 67                                       Don Mills South
# 70                                        Bathurst Manor
# 71                                       Downsview North
# 72                                        Wilson Heights
# 73                                        Northwood Park
# 74                                       York University
# 75                                           CFB Toronto
# 76                                        Downsview East
# 77                                        Downsview West
# 78                                     Downsview Central
# 79                                   Downsview Northwest
# 89                                      Victoria Village
# 90                                      Woodbine Gardens
# 91                                         Parkview Hill
# 92                                      Woodbine Heights
# 93                                           The Beaches
# 94                                               Leaside
# 95                                      Thorncliffe Park
# 96                                          East Toronto
# 97                                     The Danforth West
# 98                                             Riverdale
# 99                                      The Beaches West
# 100                                         India Bazaar
# 101                                      Studio District
# 102                                        Lawrence Park
# 103                                     Davisville North
# 104                                   North Toronto West
# 105                                           Davisville
# 106                                           Moore Park
# 107                                      Summerhill East
# 108                                            Deer Park
# 109                                       Forest Hill SE
# 110                                            Rathnelly
# 111                                           South Hill
# 112                                      Summerhill West
# 113                                             Rosedale
# 114                                          Cabbagetown
# 115                                       St. James Town
# 116                                 Church and Wellesley
# 118                                         Harbourfront
# 119                                              Ryerson
# 120                                      Garden District
# 121                                       St. James Town
# 122                                          Berczy Park
# 123                                   Central Bay Street
# 124                                             Adelaide
# 125                                                 King
# 126                                             Richmond
# 127                                    Harbourfront East
# 128                                      Toronto Islands
# 129                                        Union Station
# 130                                      Design Exchange
# 131                              Toronto Dominion Centre
# 132                                       Commerce Court
# 133                                       Victoria Hotel
# 134                                         Bedford Park
# 135                                  Lawrence Manor East
# 136                                             Roselawn
# 137                                    Forest Hill North
# 138                                     Forest Hill West
# 139                                            The Annex
# 140                                        North Midtown
# 141                                            Yorkville
# 142                                              Harbord
# 143                                University of Toronto
# 144                                            Chinatown
# 145                                          Grange Park
# 146                                    Kensington Market
# 147                                             CN Tower
# 148                                        Bathurst Quay
# 149                                       Island airport
# 150                                    Harbourfront West
# 151                                     King and Spadina
# 152                                        Railway Lands
# 153                                        South Niagara
# 154                      Stn A PO Boxes 25 The Esplanade
# 155                                 First Canadian Place
# 156                                     Underground city
# 159                                     Lawrence Heights
# 160                                       Lawrence Manor
# 161                                            Glencairn
# 162                                   Humewood-Cedarvale
# 163                                  Caledonia-Fairbanks
# 164                                             Christie
# 165                                   Dovercourt Village
# 166                                             Dufferin
# 167                                      Little Portugal
# 168                                              Trinity
# 169                                             Brockton
# 170                                     Exhibition Place
# 171                                     Parkdale Village
# 172                                            Downsview
# 173                                           North Park
# 174                                          Upwood Park
# 175                                              Del Ray
# 176                                           Keelesdale
# 177                                         Mount Dennis
# 178                                          Silverthorn
# 179                                   The Junction North
# 180                                            Runnymede
# 181                                            High Park
# 182                                   The Junction South
# 183                                             Parkdale
# 184                                         Roncesvalles
# 185                                            Runnymede
# 186                                              Swansea
# 193                                         Not assigned
# 205                Canada Post Gateway Processing Centre
# 211    Business Reply Mail Processing Centre 969 Eastern
# 228                                    Humber Bay Shores
# 229                                         Mimico South
# 230                                          New Toronto
# 231                                            Alderwood
# 232                                          Long Branch
# 233                                         The Kingsway
# 234                                      Montgomery Road
# 235                                       Old Mill North
# 236                                           Humber Bay
# 237                                     King's Mill Park
# 238                             Kingsway Park South East
# 239                                            Mimico NE
# 240                                       Old Mill South
# 241                                   The Queensway East
# 242                                Royal York South East
# 243                                             Sunnylea
# 244                             Kingsway Park South West
# 245                                            Mimico NW
# 246                                   The Queensway West
# 247                                Royal York South West
# 248                                       South of Bloor
# 249                                         Queen's Park
# 250                                           Cloverdale
# 251                                            Islington
# 252                                         Martin Grove
# 253                                     Princess Gardens
# 254                                      West Deane Park
# 255                                    Bloordale Gardens
# 256                                             Eringate
# 257                                        Markland Wood
# 258                                    Old Burnhamthorpe
# 264                                        Humber Summit
# 265                                                Emery
# 266                                            Humberlea
# 267                                               Weston
# 268                                            Westmount
# 269                                    Kingsview Village
# 270                                 Martin Grove Gardens
# 271                                     Richview Gardens
# 272                                         St. Phillips
# 275                                       Albion Gardens
# 276                                     Beaumond Heights
# 277                                           Humbergate
# 278                                            Jamestown
# 279                                          Mount Olive
# 280                                          Silverstone
# 281                                        South Steeles
# 282                                          Thistletown
# 283                                            Northwest
# Name: Neighborhood, dtype: object

# %%
Canada_df.groupby('Postcode').agg(lambda x: x.tolist())
# Out:
#                                                     Borough  \
# Postcode
# M1B                              [Scarborough, Scarborough]
# M1C                 [Scarborough, Scarborough, Scarborough]
# M1E                 [Scarborough, Scarborough, Scarborough]
# M1G                                           [Scarborough]
# M1H                                           [Scarborough]
# M1J                                           [Scarborough]
# M1K                 [Scarborough, Scarborough, Scarborough]
# M1L                 [Scarborough, Scarborough, Scarborough]
# M1M                 [Scarborough, Scarborough, Scarborough]
# M1N                              [Scarborough, Scarborough]
# M1P                 [Scarborough, Scarborough, Scarborough]
# M1R                              [Scarborough, Scarborough]
# M1S                                           [Scarborough]
# M1T                 [Scarborough, Scarborough, Scarborough]
# M1V       [Scarborough, Scarborough, Scarborough, Scarbo...
# M1W                                           [Scarborough]
# M1X                                           [Scarborough]
# M2H                                            [North York]
# M2J                    [North York, North York, North York]
# M2K                                            [North York]
# M2L                                [North York, North York]
# M2M                                [North York, North York]
# M2N                                            [North York]
# M2P                                            [North York]
# M2R                                            [North York]
# M3A                                            [North York]
# M3B                                            [North York]
# M3C                                [North York, North York]
# M3H                    [North York, North York, North York]
# M3J                                [North York, North York]
# M3K                                [North York, North York]
# M3L                                            [North York]
# M3M                                            [North York]
# M3N                                            [North York]
# M4A                                            [North York]
# M4B                                  [East York, East York]
# M4C                                             [East York]
# M4E                                          [East Toronto]
# M4G                                             [East York]
# M4H                                             [East York]
# M4J                                             [East York]
# M4K                            [East Toronto, East Toronto]
# M4L                            [East Toronto, East Toronto]
# M4M                                          [East Toronto]
# M4N                                       [Central Toronto]
# M4P                                       [Central Toronto]
# M4R                                       [Central Toronto]
# M4S                                       [Central Toronto]
# M4T                      [Central Toronto, Central Toronto]
# M4V       [Central Toronto, Central Toronto, Central Tor...
# M4W                                      [Downtown Toronto]
# M4X                    [Downtown Toronto, Downtown Toronto]
# M4Y                                      [Downtown Toronto]
# M5A                                      [Downtown Toronto]
# M5B                    [Downtown Toronto, Downtown Toronto]
# M5C                                      [Downtown Toronto]
# M5E                                      [Downtown Toronto]
# M5G                                      [Downtown Toronto]
# M5H       [Downtown Toronto, Downtown Toronto, Downtown ...
# M5J       [Downtown Toronto, Downtown Toronto, Downtown ...
# M5K                    [Downtown Toronto, Downtown Toronto]
# M5L                    [Downtown Toronto, Downtown Toronto]
# M5M                                [North York, North York]
# M5N                                       [Central Toronto]
# M5P                      [Central Toronto, Central Toronto]
# M5R       [Central Toronto, Central Toronto, Central Tor...
# M5S                    [Downtown Toronto, Downtown Toronto]
# M5T       [Downtown Toronto, Downtown Toronto, Downtown ...
# M5V       [Downtown Toronto, Downtown Toronto, Downtown ...
# M5W                                      [Downtown Toronto]
# M5X                    [Downtown Toronto, Downtown Toronto]
# M6A                                [North York, North York]
# M6B                                            [North York]
# M6C                                                  [York]
# M6E                                                  [York]
# M6G                                      [Downtown Toronto]
# M6H                            [West Toronto, West Toronto]
# M6J                            [West Toronto, West Toronto]
# M6K              [West Toronto, West Toronto, West Toronto]
# M6L                    [North York, North York, North York]
# M6M                                [York, York, York, York]
# M6N                                            [York, York]
# M6P                            [West Toronto, West Toronto]
# M6R                            [West Toronto, West Toronto]
# M6S                            [West Toronto, West Toronto]
# M7A                                          [Queen's Park]
# M7R                                           [Mississauga]
# M7Y                                          [East Toronto]
# M8V                       [Etobicoke, Etobicoke, Etobicoke]
# M8W                                  [Etobicoke, Etobicoke]
# M8X                       [Etobicoke, Etobicoke, Etobicoke]
# M8Y       [Etobicoke, Etobicoke, Etobicoke, Etobicoke, E...
# M8Z       [Etobicoke, Etobicoke, Etobicoke, Etobicoke, E...
# M9A                                      [Downtown Toronto]
# M9B       [Etobicoke, Etobicoke, Etobicoke, Etobicoke, E...
# M9C            [Etobicoke, Etobicoke, Etobicoke, Etobicoke]
# M9L                                            [North York]
# M9M                                [North York, North York]
# M9N                                                  [York]
# M9P                                             [Etobicoke]
# M9R            [Etobicoke, Etobicoke, Etobicoke, Etobicoke]
# M9V       [Etobicoke, Etobicoke, Etobicoke, Etobicoke, E...
# M9W                                             [Etobicoke]
#
#                                                Neighborhood
# Postcode
# M1B                                        [Rouge, Malvern]
# M1C                [Highland Creek, Rouge Hill, Port Union]
# M1E                     [Guildwood, Morningside, West Hill]
# M1G                                                [Woburn]
# M1H                                             [Cedarbrae]
# M1J                                   [Scarborough Village]
# M1K           [East Birchmount Park, Ionview, Kennedy Park]
# M1L                       [Clairlea, Golden Mile, Oakridge]
# M1M       [Cliffcrest, Cliffside, Scarborough Village West]
# M1N                           [Birch Cliff, Cliffside West]
# M1P       [Dorset Park, Scarborough Town Centre, Wexford...
# M1R                                     [Maryvale, Wexford]
# M1S                                             [Agincourt]
# M1T               [Clarks Corners, Sullivan, Tam O'Shanter]
# M1V       [Agincourt North, L'Amoreaux East, Milliken, S...
# M1W                                       [L'Amoreaux West]
# M1X                                           [Upper Rouge]
# M2H                                     [Hillcrest Village]
# M2J                          [Fairview, Henry Farm, Oriole]
# M2K                                       [Bayview Village]
# M2L                              [Silver Hills, York Mills]
# M2M                               [Newtonbrook, Willowdale]
# M2N                                      [Willowdale South]
# M2P                                       [York Mills West]
# M2R                                       [Willowdale West]
# M3A                                             [Parkwoods]
# M3B                                       [Don Mills North]
# M3C                      [Flemingdon Park, Don Mills South]
# M3H       [Bathurst Manor, Downsview North, Wilson Heights]
# M3J                       [Northwood Park, York University]
# M3K                           [CFB Toronto, Downsview East]
# M3L                                        [Downsview West]
# M3M                                     [Downsview Central]
# M3N                                   [Downsview Northwest]
# M4A                                      [Victoria Village]
# M4B                       [Woodbine Gardens, Parkview Hill]
# M4C                                      [Woodbine Heights]
# M4E                                           [The Beaches]
# M4G                                               [Leaside]
# M4H                                      [Thorncliffe Park]
# M4J                                          [East Toronto]
# M4K                          [The Danforth West, Riverdale]
# M4L                        [The Beaches West, India Bazaar]
# M4M                                       [Studio District]
# M4N                                         [Lawrence Park]
# M4P                                      [Davisville North]
# M4R                                    [North Toronto West]
# M4S                                            [Davisville]
# M4T                           [Moore Park, Summerhill East]
# M4V       [Deer Park, Forest Hill SE, Rathnelly, South H...
# M4W                                              [Rosedale]
# M4X                           [Cabbagetown, St. James Town]
# M4Y                                  [Church and Wellesley]
# M5A                                          [Harbourfront]
# M5B                              [Ryerson, Garden District]
# M5C                                        [St. James Town]
# M5E                                           [Berczy Park]
# M5G                                    [Central Bay Street]
# M5H                              [Adelaide, King, Richmond]
# M5J       [Harbourfront East, Toronto Islands, Union Sta...
# M5K              [Design Exchange, Toronto Dominion Centre]
# M5L                        [Commerce Court, Victoria Hotel]
# M5M                     [Bedford Park, Lawrence Manor East]
# M5N                                              [Roselawn]
# M5P                   [Forest Hill North, Forest Hill West]
# M5R                   [The Annex, North Midtown, Yorkville]
# M5S                        [Harbord, University of Toronto]
# M5T             [Chinatown, Grange Park, Kensington Market]
# M5V       [CN Tower, Bathurst Quay, Island airport, Harb...
# M5W                       [Stn A PO Boxes 25 The Esplanade]
# M5X                [First Canadian Place, Underground city]
# M6A                      [Lawrence Heights, Lawrence Manor]
# M6B                                             [Glencairn]
# M6C                                    [Humewood-Cedarvale]
# M6E                                   [Caledonia-Fairbanks]
# M6G                                              [Christie]
# M6H                          [Dovercourt Village, Dufferin]
# M6J                              [Little Portugal, Trinity]
# M6K          [Brockton, Exhibition Place, Parkdale Village]
# M6L                    [Downsview, North Park, Upwood Park]
# M6M        [Del Ray, Keelesdale, Mount Dennis, Silverthorn]
# M6N                         [The Junction North, Runnymede]
# M6P                         [High Park, The Junction South]
# M6R                                [Parkdale, Roncesvalles]
# M6S                                    [Runnymede, Swansea]
# M7A                                          [Not assigned]
# M7R                 [Canada Post Gateway Processing Centre]
# M7Y       [Business Reply Mail Processing Centre 969 Eas...
# M8V          [Humber Bay Shores, Mimico South, New Toronto]
# M8W                                [Alderwood, Long Branch]
# M8X         [The Kingsway, Montgomery Road, Old Mill North]
# M8Y       [Humber Bay, King's Mill Park, Kingsway Park S...
# M8Z       [Kingsway Park South West, Mimico NW, The Quee...
# M9A                                          [Queen's Park]
# M9B       [Cloverdale, Islington, Martin Grove, Princess...
# M9C       [Bloordale Gardens, Eringate, Markland Wood, O...
# M9L                                         [Humber Summit]
# M9M                                      [Emery, Humberlea]
# M9N                                                [Weston]
# M9P                                             [Westmount]
# M9R       [Kingsview Village, Martin Grove Gardens, Rich...
# M9V       [Albion Gardens, Beaumond Heights, Humbergate,...
# M9W                                             [Northwest]

# %%
Canada_df.shape
# Out:
# (210, 3)

# %%
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-11-0106f2bb058e> in <module>()
# ----> 1 import conda
#
# ImportError: No module named 'conda'

# %%
import geocoder # import geocoder

# initialize your variable to None
lat_lng_coords = None

# loop until you get the coordinates
while(lat_lng_coords is None):
  g = geocoder.google('{}, Toronto, Ontario'.format(postal_code))
  lat_lng_coords = g.latlng

latitude = lat_lng_coords[0]
longitude = lat_lng_coords[1]
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-9-f9a1a3d479bb> in <module>()
# ----> 1 import geocoder # import geocoder
#       2
#       3 # initialize your variable to None
#       4 lat_lng_coords = None
#       5
#
# ImportError: No module named 'geocoder'

# %%
address = 'Toronto, Ontario'

geolocator = Nominatim(user_agent="Toronto_explorer")
location = geolocator.geocode(address)
latitude = location.latitude
longitude = location.longitude
print('The geograpical coordinate of Toronto, Ontario are {}, {}.'.format(latitude, longitude))

# %%
neighborhoods.head()

# %%
# create map of Toronto, Ontario using latitude and longitude values
map_newyork = folium.Map(location=[latitude, longitude], zoom_start=10)

# add markers to map
for lat, lng, borough, neighborhood in zip(neighborhoods['Latitude'], neighborhoods['Longitude'], neighborhoods['Borough'], neighborhoods['Neighborhood']):
    label = '{}, {}'.format(neighborhood, borough)
    label = folium.Popup(label, parse_html=True)
    folium.CircleMarker(
        [lat, lng],
        radius=5,
        popup=label,
        color='blue',
        fill=True,
        fill_color='#3186cc',
        fill_opacity=0.7,
        parse_html=False).add_to(map_Toronto)  
    
map_newyork

# %%
address = 'Toronto, Ontario'

geolocator = Nominatim(user_agent="Toronto_explorer")
location = geolocator.geocode(address)
latitude = location.latitude
longitude = location.longitude
print('The geograpical coordinate of Manhattan are {}, {}.'.format(latitude, longitude))

# %%
# create map of Toronto, Ontario using latitude and longitude values
map_manhattan = folium.Map(location=[latitude, longitude], zoom_start=11)

# add markers to map
for lat, lng, label in zip(manhattan_data['Latitude'], manhattan_data['Longitude'], manhattan_data['Neighborhood']):
    label = folium.Popup(label, parse_html=True)
    folium.CircleMarker(
        [lat, lng],
        radius=5,
        popup=label,
        color='blue',
        fill=True,
        fill_color='#3186cc',
        fill_opacity=0.7,
        parse_html=False).add_to(map_Torontoa)  
    
map_manhattan

# %%
k means

# %%
df = customers_df.drop('Address', axis=1)
df.head()

# %%
from sklearn.preprocessing import StandardScaler

X = df.values[:,1:]
X = np.nan_to_num(X)
cluster_dataset = StandardScaler().fit_transform(X)
cluster_dataset

# %%
num_clusters = 3

k_means = KMeans(init="k-means++", n_clusters=num_clusters, n_init=12)
k_means.fit(cluster_dataset)
labels = k_means.labels_

print(labels)

# %%
df["Labels"] = labels
df.head(5)

# %%
df.groupby('Labels').mean()
