# %%
import requests # library to handle requests
import pandas as pd # library for data analsysis
import numpy as np # library to handle data in a vectorized manner
import random # library for random number generation

# !conda install -c conda-forge geopy --yes 
from geopy.geocoders import Nominatim # module to convert an address into latitude and longitude values

# libraries for displaying images
from IPython.display import Image 
from IPython.core.display import HTML 
    
# tranforming json file into a pandas dataframe library
from pandas.io.json import json_normalize

# !conda install -c conda-forge folium=0.5.0 --yes
import folium # plotting library

print('Folium installed')
print('Libraries imported.')
# Out:
# Solving environment: done
#
#
# ==> WARNING: A newer version of conda exists. <==
#   current version: 4.5.11
#   latest version: 4.8.0
#
# Please update conda by running
#
#     $ conda update -n base conda
#
#
#
# ## Package Plan ##
#
#   environment location: /opt/anaconda3
#
#   added / updated specs:
#     - geopy
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     xz-5.2.4                   |    h14c3975_1001         368 KB  conda-forge
#     openssl-1.0.2u             |       h7b6447c_0         2.9 MB  anaconda
#     sqlite-3.13.0              |                0         5.0 MB  anaconda
#     python-3.6.2               |                0        19.0 MB  anaconda
#     pip-19.3.1                 |           py36_0         1.9 MB  conda-forge
#     libgcc-ng-8.2.0            |       h822a55f_2         8.0 MB  conda-forge
# ...

# %%
CLIENT_ID = 'K0I05NJ3O323WX05GKGKKIWDHEAJQ0T35A10VYHMMKKPWYYT' # your Foursquare ID
CLIENT_SECRET = 'O42XRWZSHU2LMCAHP50EFELPHNNVZWBVAVG3PKAT5XTG31LA' # your Foursquare Secret
VERSION = '20180604'
LIMIT = 30
print('Your credentails:')
print('CLIENT_ID: ' + CLIENT_ID)
print('CLIENT_SECRET:' + CLIENT_SECRET)
# Out:
# Your credentails:
# CLIENT_ID: K0I05NJ3O323WX05GKGKKIWDHEAJQ0T35A10VYHMMKKPWYYT
# CLIENT_SECRET:O42XRWZSHU2LMCAHP50EFELPHNNVZWBVAVG3PKAT5XTG31LA

# %%
address = '3209 Bending Birch Pl, Charlotte, NC'

geolocator = Nominatim(user_agent="foursquare_agent")
location = geolocator.geocode(address)
latitude = location.latitude
longitude = location.longitude
print(latitude, longitude)
# Out:
# 35.2527469309212 -80.8388309494152

# %%
search_query = 'Indian'
radius = 10000
print(search_query + ' .... OK!')
# Out:
# Indian .... OK!

# %%
url = 'https://api.foursquare.com/v2/venues/search?client_id={}&client_secret={}&ll={},{}&v={}&query={}&radius={}&limit={}'.format(CLIENT_ID, CLIENT_SECRET, latitude, longitude, VERSION, search_query, radius, LIMIT)
url
# Out:
# 'https://api.foursquare.com/v2/venues/search?client_id=K0I05NJ3O323WX05GKGKKIWDHEAJQ0T35A10VYHMMKKPWYYT&client_secret=O42XRWZSHU2LMCAHP50EFELPHNNVZWBVAVG3PKAT5XTG31LA&ll=35.2527469309212,-80.8388309494152&v=20180604&query=Indian&radius=10000&limit=30'

# %%
results = requests.get(url).json()
results
# Out:
# {'meta': {'code': 200, 'requestId': '5e1146e8c94979001bfe9597'},
#  'response': {'venues': [{'id': '4b23f452f964a520b85d24e3',
#     'name': 'Jaipur Indian Cuisine',
#     'location': {'address': '5909 South Blvd',
#      'crossStreet': 'N of Archdale Dr',
#      'lat': 35.15537290148843,
#      'lng': -80.8754783927745,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 35.15537290148843,
#        'lng': -80.8754783927745}],
#      'distance': 11340,
#      'postalCode': '28217',
#      'cc': 'US',
#      'city': 'Charlotte',
#      'state': 'NC',
#      'country': 'United States',
#      'formattedAddress': ['5909 South Blvd (N of Archdale Dr)',
#       'Charlotte, NC 28217',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d10f941735',
#       'name': 'Indian Restaurant',
#       'pluralName': 'Indian Restaurants',
#       'shortName': 'Indian',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/indian_',
# ...

# %%
# assign relevant part of JSON to venues
venues = results['response']['venues']

# tranform venues into a dataframe
dataframe = json_normalize(venues)
dataframe.head()
# Out:
#                                           categories delivery.id  \
# 0  [{'id': '4bf58dd8d48988d10f941735', 'name': 'I...      348015
# 1  [{'id': '4bf58dd8d48988d10f941735', 'name': 'I...     1407050
# 2  [{'id': '4bf58dd8d48988d10f941735', 'name': 'I...         NaN
# 3  [{'id': '4bf58dd8d48988d10f941735', 'name': 'I...         NaN
# 4  [{'id': '4bf58dd8d48988d10f941735', 'name': 'I...     1314007
#
#                delivery.provider.icon.name  \
# 0  /delivery_provider_grubhub_20180129.png
# 1  /delivery_provider_grubhub_20180129.png
# 2                                      NaN
# 3                                      NaN
# 4  /delivery_provider_grubhub_20180129.png
#
#               delivery.provider.icon.prefix delivery.provider.icon.sizes  \
# 0  https://fastly.4sqi.net/img/general/cap/                     [40, 50]
# 1  https://fastly.4sqi.net/img/general/cap/                     [40, 50]
# 2                                       NaN                          NaN
# ...

# %%
# keep only columns that include venue name, and anything that is associated with location
filtered_columns = ['name', 'categories'] + [col for col in dataframe.columns if col.startswith('location.')] + ['id']
dataframe_filtered = dataframe.loc[:, filtered_columns]

# function that extracts the category of the venue
def get_category_type(row):
    try:
        categories_list = row['categories']
    except:
        categories_list = row['venue.categories']
        
    if len(categories_list) == 0:
        return None
    else:
        return categories_list[0]['name']

# filter the category for each row
dataframe_filtered['categories'] = dataframe_filtered.apply(get_category_type, axis=1)

# clean column names by keeping only last term
dataframe_filtered.columns = [column.split('.')[-1] for column in dataframe_filtered.columns]

dataframe_filtered
# Out:
#                                                 name               categories  \
# 0                              Jaipur Indian Cuisine        Indian Restaurant
# 1                            Maharani Indian Cuisine        Indian Restaurant
# 2                        Persis Biryani Indian Grill        Indian Restaurant
# 3                               Aroma Indian Cuisine        Indian Restaurant
# 4                                     Sithara indian        Indian Restaurant
# 5                        Persis Biryani Indian Grill        Indian Restaurant
# 6                             Indian Head Industries                   Office
# 7                                      Indian Market                     None
# 8                           Copper Indian Restaurant        Indian Restaurant
# 9                            Godavari Indian Cuisine        Indian Restaurant
# 10                             Tandur Indian Kitchen        Indian Restaurant
# ...

# %%
dataframe_filtered.name
# Out:
# 0                                Jaipur Indian Cuisine
# 1                              Maharani Indian Cuisine
# 2                          Persis Biryani Indian Grill
# 3                                 Aroma Indian Cuisine
# 4                                       Sithara indian
# 5                          Persis Biryani Indian Grill
# 6                               Indian Head Industries
# 7                                        Indian Market
# 8                             Copper Indian Restaurant
# 9                              Godavari Indian Cuisine
# 10                               Tandur Indian Kitchen
# 11                                Persis Indian Grille
# 12                                 Clove Indian Cusine
# 13    Monroe Convenience Store & Nepali/Indian Grocery
# 14                           Peacock Indian Restaurant
# 15            Woodlands Pure Vegetarian Indian Cuisine
# 16                         Pudina Fresh Indian Cuisine
# ...

# %% [markdown]
# ## MAP OUT THE LOCATIONS....

# %%
venues_map = folium.Map(location=[latitude, longitude], zoom_start=13) # generate map 

venues_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
venues_map = folium.Map(location=[latitude, longitude], zoom_start=13) # generate map centred around the Conrad Hotel

# add a red circle marker to represent the Conrad Hotel
folium.features.CircleMarker(
    [latitude, longitude],
    radius=10,
    color='red',
    popup='Maharani Restuarant',
    fill = True,
    fill_color = 'red',
    fill_opacity = 0.6
).add_to(venues_map)

# add the Italian restaurants as blue circle markers
for lat, lng, label in zip(dataframe_filtered.lat, dataframe_filtered.lng, dataframe_filtered.categories):
    folium.features.CircleMarker(
        [lat, lng],
        radius=5,
        color='blue',
        popup=label,
        fill = True,
        fill_color='blue',
        fill_opacity=0.6
    ).add_to(venues_map)

# display map
venues_map

# %%
venue_id = '4b2d343cf964a520efd024e3' # ID of Maharani
url = 'https://api.foursquare.com/v2/venues/{}?client_id={}&client_secret={}&v={}'.format(venue_id, CLIENT_ID, CLIENT_SECRET, VERSION)
url
# Out:
# 'https://api.foursquare.com/v2/venues/4b2d343cf964a520efd024e3?client_id=K0I05NJ3O323WX05GKGKKIWDHEAJQ0T35A10VYHMMKKPWYYT&client_secret=O42XRWZSHU2LMCAHP50EFELPHNNVZWBVAVG3PKAT5XTG31LA&v=20180604'

# %%
result = requests.get(url).json()
print(result['response']['venue'].keys())
result['response']['venue']
# Out:
# dict_keys(['id', 'name', 'contact', 'location', 'canonicalUrl', 'categories', 'verified', 'stats', 'url', 'price', 'hasMenu', 'likes', 'dislike', 'ok', 'rating', 'ratingColor', 'ratingSignals', 'delivery', 'menu', 'allowMenuUrlEdit', 'beenHere', 'specials', 'photos', 'reasons', 'hereNow', 'createdAt', 'tips', 'shortUrl', 'timeZone', 'listed', 'hours', 'popular', 'pageUpdates', 'inbox', 'attributes', 'bestPhoto', 'colors'])
# {'id': '4b2d343cf964a520efd024e3',
#  'name': 'Maharani Indian Cuisine',
#  'contact': {'phone': '7043702455', 'formattedPhone': '(704) 370-2455'},
#  'location': {'address': '901 S Kings Dr Ste 115',
#   'crossStreet': 'at Morehead',
#   'lat': 35.20684662427658,
#   'lng': -80.83558483746312,
#   'labeledLatLngs': [{'label': 'display',
#     'lat': 35.20684662427658,
#     'lng': -80.83558483746312}],
#   'postalCode': '28204',
#   'cc': 'US',
#   'city': 'Charlotte',
#   'state': 'NC',
#   'country': 'United States',
# ...

# %%
try:
    print(result['response']['venue']['rating'])
except:
    print('This venue has not been rated yet.')
# Out:
# 7.1

# %% [markdown]
# ## NOW LETS SEARCH FOR AN ITALIAN RESTAURANT WITHIN A SMALL RADIUS OF THIS INDIAN RESTAURANT!!

# %%
address = '901 S Kings Dr, Charlotte, NC'

geolocator = Nominatim(user_agent="foursquare_agent")
location = geolocator.geocode(address)
latitude = location.latitude
longitude = location.longitude
print(latitude, longitude)
# Out:
# 35.206608 -80.83597

# %%
search_query = 'Italian'
radius = 6000
print(search_query + ' .... OK!')
# Out:
# Italian .... OK!

# %%
url = 'https://api.foursquare.com/v2/venues/search?client_id={}&client_secret={}&ll={},{}&v={}&query={}&radius={}&limit={}'.format(CLIENT_ID, CLIENT_SECRET, latitude, longitude, VERSION, search_query, radius, LIMIT)
url
# Out:
# 'https://api.foursquare.com/v2/venues/search?client_id=K0I05NJ3O323WX05GKGKKIWDHEAJQ0T35A10VYHMMKKPWYYT&client_secret=O42XRWZSHU2LMCAHP50EFELPHNNVZWBVAVG3PKAT5XTG31LA&ll=35.206608,-80.83597&v=20180604&query=Italian&radius=6000&limit=30'

# %%
results = requests.get(url).json()
results
# Out:
# {'meta': {'code': 200, 'requestId': '5e114ebbbae9a2001caa4a03'},
#  'response': {'venues': [{'id': '4b1e7a41f964a520591a24e3',
#     'name': 'Vivace Italian Restaurant',
#     'location': {'address': '1100 Metropolitan Ave Ste 100 Bldg E',
#      'lat': 35.21205953317677,
#      'lng': -80.83640204680589,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 35.21205953317677,
#        'lng': -80.83640204680589}],
#      'distance': 608,
#      'postalCode': '28204',
#      'cc': 'US',
#      'city': 'Charlotte',
#      'state': 'NC',
#      'country': 'United States',
#      'formattedAddress': ['1100 Metropolitan Ave Ste 100 Bldg E',
#       'Charlotte, NC 28204',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d110941735',
#       'name': 'Italian Restaurant',
#       'pluralName': 'Italian Restaurants',
#       'shortName': 'Italian',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/italian_',
#        'suffix': '.png'},
# ...

# %%
# assign relevant part of JSON to venues
venues = results['response']['venues']

# tranform venues into a dataframe
dataframe = json_normalize(venues)
dataframe.head()
# Out:
#                                           categories delivery.id  \
# 0  [{'id': '4bf58dd8d48988d110941735', 'name': 'I...     1321639
# 1  [{'id': '4bf58dd8d48988d1c9941735', 'name': 'I...     1470693
# 2  [{'id': '4bf58dd8d48988d1ca941735', 'name': 'P...         NaN
# 3  [{'id': '4bf58dd8d48988d110941735', 'name': 'I...     1311388
# 4  [{'id': '4bf58dd8d48988d110941735', 'name': 'I...         NaN
#
#                delivery.provider.icon.name  \
# 0  /delivery_provider_grubhub_20180129.png
# 1  /delivery_provider_grubhub_20180129.png
# 2                                      NaN
# 3  /delivery_provider_grubhub_20180129.png
# 4                                      NaN
#
#               delivery.provider.icon.prefix delivery.provider.icon.sizes  \
# 0  https://fastly.4sqi.net/img/general/cap/                     [40, 50]
# 1  https://fastly.4sqi.net/img/general/cap/                     [40, 50]
# 2                                       NaN                          NaN
# ...

# %%
# keep only columns that include venue name, and anything that is associated with location
filtered_columns = ['name', 'categories'] + [col for col in dataframe.columns if col.startswith('location.')] + ['id']
dataframe_filtered = dataframe.loc[:, filtered_columns]

# function that extracts the category of the venue
def get_category_type(row):
    try:
        categories_list = row['categories']
    except:
        categories_list = row['venue.categories']
        
    if len(categories_list) == 0:
        return None
    else:
        return categories_list[0]['name']

# filter the category for each row
dataframe_filtered['categories'] = dataframe_filtered.apply(get_category_type, axis=1)

# clean column names by keeping only last term
dataframe_filtered.columns = [column.split('.')[-1] for column in dataframe_filtered.columns]

dataframe_filtered
# Out:
#                                    name          categories  \
# 0             Vivace Italian Restaurant  Italian Restaurant
# 1   Rita's Italian Ice & Frozen Custard      Ice Cream Shop
# 2                 Italian Village Pizza         Pizza Place
# 3                    Zio Casual Italian  Italian Restaurant
# 4             Volare Italian Restaurant  Italian Restaurant
# 5                          Italian @7th  Italian Restaurant
# 6               Frankie's Italian Grill  Italian Restaurant
# 7                 Zio Authentic Italian  Italian Restaurant
# 8         Capishe: Real Italian Kitchen         Pizza Place
# 9     Zia Pia imports + Italian kitchen  Italian Restaurant
# 10                Verona Italian Eatery                Food
# 11          Lindys Homemade Italian Ice        Dessert Shop
# 12                    ritas italian ice      Ice Cream Shop
# 13              Napolitano's Food Truck          Food Truck
# 14                Portofino's Park Road  Italian Restaurant
# ...

# %%
dataframe_filtered.name
# Out:
# 0               Vivace Italian Restaurant
# 1     Rita's Italian Ice & Frozen Custard
# 2                   Italian Village Pizza
# 3                      Zio Casual Italian
# 4               Volare Italian Restaurant
# 5                            Italian @7th
# 6                 Frankie's Italian Grill
# 7                   Zio Authentic Italian
# 8           Capishe: Real Italian Kitchen
# 9       Zia Pia imports + Italian kitchen
# 10                  Verona Italian Eatery
# 11            Lindys Homemade Italian Ice
# 12                      ritas italian ice
# 13                Napolitano's Food Truck
# 14                  Portofino's Park Road
# 15                    Portofino's Eastway
# 16                  Fresh Italian Kitchen
# 17       Sunset Slush Classic Italian Ice
# 18                     Brio Tuscan Grille
# Name: name, dtype: object

# %% [markdown]
# ## It seems that our prime location would be somewhere between Maharani Indian Restaurant and Vivace Italian Restaurant

# %%
venues_map = folium.Map(location=[latitude, longitude], zoom_start=13) # generate map centred around the Conrad Hotel

# display map
venues_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
venues_map = folium.Map(location=[latitude, longitude], zoom_start=13) # generate map centred around the Conrad Hotel

# add a red circle marker to represent the Conrad Hotel
folium.features.CircleMarker(
    [latitude, longitude],
    radius=10,
    color='red',
    popup='Maharani',
    fill = True,
    fill_color = 'red',
    fill_opacity = 0.6
).add_to(venues_map)

# add the Italian restaurants as blue circle markers
for lat, lng, label in zip(dataframe_filtered.lat, dataframe_filtered.lng, dataframe_filtered.categories):
    folium.features.CircleMarker(
        [lat, lng],
        radius=5,
        color='blue',
        popup=label,
        fill = True,
        fill_color='blue',
        fill_opacity=0.6
    ).add_to(venues_map)

# display map
venues_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# # It looks like this is our best location to place a food truck!!
